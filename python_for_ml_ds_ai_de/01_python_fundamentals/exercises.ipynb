# %% [markdown]
# # Module 01 Exercises
#
# Attempt all exercises before looking at solutions.

# %% [markdown]
# ## Exercise 1: Temperature Converter
#
# Convert 100F to Celsius: (F - 32) * 5/9. Print with f-string to 1 decimal.

# %%
f = 100
# Your code here

# %% [markdown]
# ## Exercise 2: List Statistics
#
# For scores=[85,92,78,95,88,72,90], find min, max, sum, mean, count above 80.

# %%
scores = [85, 92, 78, 95, 88, 72, 90]
# Your code here

# %% [markdown]
# ## Exercise 3: Data Cleaner
#
# Parse "Alice,25,Engineer|Bob,30,Doctor|Charlie,35,Teacher" into a list of dicts.

# %%
raw = "Alice,25,Engineer|Bob,30,Doctor|Charlie,35,Teacher"
# Your code here

# %% [markdown]
# ## Exercise 4: Word Frequency
#
# Count word occurrences in text (ignore case, remove punctuation).

# %%
text = "the quick brown fox jumps over the lazy dog. The dog barks!"
# Your code here

# %% [markdown]
# ## Exercise 5: Set Operations
#
# Two lists of IDs. Find: in both, only in A, total unique.

# %%
A, B = [101,102,103,104,105], [103,104,106,107,108]
# Your code here

# %% [markdown]
# ## Exercise 6: Nested Dict
#
# Safely extract Charlie's second subject from nested dict.

# %%
students = {
    "Alice": {"subjects": ["Math", "Physics"]},
    "Bob": {"subjects": ["CS", "Stats"]},
    "Charlie": {"subjects": ["ML", "Data Mining"]}
}
# Your code here
