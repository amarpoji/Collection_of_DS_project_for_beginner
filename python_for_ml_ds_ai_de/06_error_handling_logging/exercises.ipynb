# %% [markdown]
# # Module 06: Error Handling & Logging — Exercises
#
# Practice building robust ML pipelines with proper error handling and logging.

# %% [markdown]
# ## Exercise 1: Safe Division
#
# Write a function `safe_divide(a, b)` that:
# 1. Tries to divide `a` by `b`
# 2. Catches `ZeroDivisionError` and prints a message
# 3. Catches `TypeError` (if inputs are not numbers) and prints a message
# 4. Returns the result or `None` if an error occurred
# 5. Prints "Operation attempted" in a `finally` block

# %%
# Your code here


# Test cases
print('Test 1:', safe_divide(10, 2))
print('Test 2:', safe_divide(10, 0))
print('Test 3:', safe_divide(10, 'a'))

# %% [markdown]
# ## Exercise 2: Custom Exception for Data Validation
#
# Create a custom exception `DataQualityError`.
#
# Write a function `check_data_quality(data)` that:
# 1. Takes a list of numbers
# 2. Raises `DataQualityError` if the list is empty
# 3. Raises `DataQualityError` if any value is negative
# 4. Raises `DataQualityError` if any value is not a number (hint: check type)
# 5. Returns the mean if all checks pass
#
# Test with multiple cases.

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Logging Setup
#
# Set up a logger called `'ml_pipeline'` that:
# 1. Logs to console at INFO level with format: `%(levelname)s: %(message)s`
# 2. Logs to a file `ml_pipeline.log` at DEBUG level with format: `%(asctime)s - %(message)s`
# 3. Logs these messages in order:
#    - DEBUG: "Initializing pipeline"
#    - INFO: "Loading dataset"
#    - WARNING: "Dataset has 10% missing values"
#    - INFO: "Training started"
#    - ERROR: "Training failed: NaN detected"

# %%
# Your code here
import logging

# %% [markdown]
# ## Exercise 4: Robust File Loader
#
# Write a function `load_json_safe(path)` that:
# 1. Tries to open and parse a JSON file
# 2. If `FileNotFoundError` — creates a default config `{'status': 'default'}` and prints a warning
# 3. If `json.JSONDecodeError` — prints an error and returns an empty dict
# 4. On success — prints "Loaded successfully" and returns the data
# 5. Always prints "Load attempt completed" in finally
#
# Test with a valid file, a missing file, and a file with invalid JSON.

# %%
# Your code here
import json

# %% [markdown]
# ## Exercise 5: Training Loop with Error Handling
#
# Simulate a training loop where:
# 1. For each epoch, there's a 20% chance of a random error (simulate with `random.random() < 0.2`)
# 2. If error occurs, log it and continue to next epoch (don't crash)
# 3. Track and print: total epochs, failed epochs, successful epochs
# 4. Log at INFO level for successes, ERROR level for failures
# 5. Use a logger with console output

# %%
# Your code here
import logging
import random

# %% [markdown]
# ## Exercise 6: Pipeline with Fallback
#
# Write a function `load_dataset_or_fallback(paths)` that:
# 1. Takes a list of file paths
# 2. Tries each path in order
# 3. If a file loads successfully (simulate with `open` + check), returns it
# 4. If all fail, raises `FileNotFoundError("No data source available")`
# 5. Logs each attempt as INFO and each failure as WARNING
#
# Test with a list where only the last path exists.

# %%
# Your code here
