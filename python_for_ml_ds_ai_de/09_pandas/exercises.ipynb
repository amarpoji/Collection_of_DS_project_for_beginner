# %% [markdown]
# # Module 09: Pandas — Exercises
#
# **Dataset:** Titanic
# **Objective:** Practice pandas operations from basic to advanced
#
# Complete each exercise in the cells below. Write clean, well-commented code. Avoid chained indexing.

# %%
# Setup: run this cell first
import pandas as pd
import numpy as np

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic = pd.read_csv(url)
print('Titanic dataset loaded. Shape:', titanic.shape)

# %% [markdown]
# ### Exercise 1: Data Inspection
# Display the following:
# - First 8 rows of the dataset
# - Column names and their data types
# - Summary statistics for all numeric columns
# - Number of unique values in each column

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 2: Boolean Indexing
# Find the following subsets:
# - All female passengers who survived
# - Male passengers under 18 who did not survive
# - Passengers who paid fare greater than the 75th percentile
# - Passengers in 1st class who are older than 60

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 3: Missing Data Handling
# 1. Calculate the percentage of missing values per column
# 2. Fill missing Age values using the median age of each passenger class
# 3. Drop the Cabin column
# 4. Drop any rows that still have missing values in Embarked
# 5. Verify no missing values remain

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 4: GroupBy Operations
# 1. Calculate the survival rate by passenger class and sex
# 2. Find the average age and fare for each combination of Pclass and Embarked
# 3. For each Pclass, find the passenger with the maximum fare
# 4. Create a column showing how far each passenger's fare deviates from their Pclass average

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 5: Apply & Map
# 1. Use `.map()` to create a column 'Pclass_Name' mapping 1->'First', 2->'Second', 3->'Third'
# 2. Use `.apply()` to create a 'Has_Cabin' column (True/False) based on whether Cabin is non-null
# 3. Use `.apply(row-wise)` to create a 'Total_Family' = SibSp + Parch
# 4. Categorize 'Age' into bins using `.apply()`: 0-12 'Child', 13-19 'Teen', 20-39 'Adult', 40-59 'Middle', 60+ 'Senior'

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 6: String Operations
# Using the `.str` accessor:
# 1. Extract the title (Mr, Mrs, Miss, Master, etc.) from the Name column
# 2. Count how many names contain 'Mrs' or 'Miss'
# 3. Find all passengers whose name starts with 'A'
# 4. Create a 'Surname' column by extracting the first part of the name before the comma

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 7: Merge & Pivot Tables
# 1. Create a simple DataFrame 'deck_info' with columns ['Deck', 'Deck_Level'] where Deck = A,B,C,D,E,F,G and Deck_Level = 1,2,3,4,5,6,7
# 2. Extract deck letter from Cabin and merge with deck_info
# 3. Create a pivot table showing average fare by Pclass and Embarked
# 4. Use melt() to unpivot the pivot table from step 3

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 8: Memory Optimization
# 1. Display the memory usage of the Titanic DataFrame
# 2. Convert all object columns with < 10 unique values to 'category' dtype
# 3. Downcast float columns using pd.to_numeric with downcast='float'
# 4. Show the memory savings (original vs optimized)

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 9: Multi-Index
# 1. Set a multi-index on ['Pclass', 'Sex', 'Survived']
# 2. Sort the multi-index
# 3. Use `.xs()` to select all female survivors
# 4. Use `.xs()` to select all passengers in class 1
# 5. Calculate average age at each level of the multi-index

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 10: ML Data Preparation Pipeline
# Build an end-to-end pipeline:
# 1. Load the raw Titanic data
# 2. Impute missing Age (median by Pclass and Sex)
# 3. Create Title feature, Family_Size, Is_Alone
# 4. Encode Sex, Embarked, Title as dummy variables
# 5. Drop PassengerId, Name, Ticket, Cabin
# 6. Ensure all columns are numeric
# 7. Separate into X (features) and y (Survived)
# 8. Print shape and column list of X

# %%
# Your code here
pass
