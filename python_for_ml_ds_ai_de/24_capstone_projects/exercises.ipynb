# %% [markdown]
# # Module 24: Capstone Projects — Task Lists
#
# Detailed task lists for each of the 5 capstone projects.
# Check off tasks as you complete them.

# %% [markdown]
# ---
# ## Project 1: End-to-End ML Pipeline
#
# ### Task 1: Data Loading and Exploration
# - [ ] Load dataset using pandas.read_csv()
# - [ ] Display basic info (shape, dtypes, describe, info())
# - [ ] Check for missing values and decide on strategy
# - [ ] Visualize target variable distribution
# - [ ] Create correlation matrix heatmap
# - [ ] Identify feature types (numerical, categorical, text, date)

# %%
# Implement Task 1 here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Example: Load a dataset
# df = pd.read_csv('data/raw/housing.csv')
# print(df.info())
# print(df.describe())
# print(f"Missing values:\n{df.isnull().sum()}")

print("Start with data exploration")

# %% [markdown]
# ### Task 2: Feature Engineering
# - [ ] Handle missing values (impute or drop)
# - [ ] Create new features from existing ones
# - [ ] Encode categorical variables (OneHot/LabelEncoder)
# - [ ] Scale numerical features
# - [ ] Split data into train/test sets
# - [ ] Define ColumnTransformer and Pipeline

# %%
# Implement Task 2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

print("Build feature engineering pipeline")

# %% [markdown]
# ### Task 3: Model Training and Tuning
# - [ ] Train at least 3 different models
# - [ ] Perform cross-validation for each
# - [ ] Use GridSearchCV or RandomizedSearchCV
# - [ ] Compare results in a table
# - [ ] Select best model and retrain on full training set

# %%
# Implement Task 3
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import cross_val_score, GridSearchCV

print("Train and tune models")

# %% [markdown]
# ### Task 4: Experiment Tracking with MLflow
# - [ ] Set up MLflow tracking URI
# - [ ] Log parameters for each model
# - [ ] Log metrics (RMSE, R², MAE)
# - [ ] Log trained model as artifact
# - [ ] Log feature importance plot
# - [ ] View results in MLflow UI

# %%
# Implement Task 4
# import mlflow
# mlflow.set_tracking_uri('http://localhost:5000')
# mlflow.set_experiment('house-prices')
# with mlflow.start_run():
#     mlflow.log_params({...})
#     mlflow.log_metrics({...})
#     mlflow.sklearn.log_model(model, 'model')

print("Set up MLflow experiment tracking")

# %% [markdown]
# ### Task 5: Model Interpretation and Documentation
# - [ ] Plot feature importance
# - [ ] Create partial dependence plots
# - [ ] Write README with:
#   - Project overview
#   - Setup instructions
#   - Results and evaluation
#   - Key learnings

# %%
# Implement Task 5
print("Create documentation and interpretation")

# %% [markdown]
# ---
# ## Project 2: Data Engineering ETL Pipeline
#
# ### Task List
# - [ ] Set up project structure with src/ and tests/
# - [ ] Implement extract() for CSV source
# - [ ] Implement extract() for API source
# - [ ] Implement transform() with pandas operations
# - [ ] Implement load() to SQLite
# - [ ] Add data validation checks
# - [ ] Add logging to each step
# - [ ] Create Airflow DAG file
# - [ ] Test DAG locally
# - [ ] Write error handling with retries
# - [ ] Write README with architecture diagram
# - [ ] Add idempotency (replace vs append logic)

# %%
# Implement ETL project
print("""
Project Structure:
etl_pipeline/
  src/
    extract.py
    transform.py
    load.py
    validate.py
  dags/
    etl_dag.py
  tests/
    test_extract.py
    test_transform.py
    test_load.py
  data/
  requirements.txt
  README.md
""")

# %% [markdown]
# ---
# ## Project 3: Recommendation System
#
# ### Task List
# - [ ] Load ratings dataset (e.g., MovieLens)
# - [ ] EDA: rating distribution, user/item counts, sparsity
# - [ ] Create user-item matrix
# - [ ] Implement user-based collaborative filtering
# - [ ] Implement item-based collaborative filtering
# - [ ] Implement content-based recommendations (optional)
# - [ ] Create train/test split (temporal or random)
# - [ ] Implement precision@k and recall@k evaluation
# - [ ] Implement mean average precision (MAP)
# - [ ] Handle cold-start problem
# - [ ] Benchmark different similarity metrics
# - [ ] Write README with results and examples

# %%
# Implement recommendation project
print("""
Key metrics for evaluation:
  precision@5 = correctly recommended / 5
  recall@5 = correctly recommended / total relevant
  MAP@k = mean of average precision across users

Data: MovieLens 100K
  users: 943
  items: 1682
  ratings: 100,000
  sparsity: 93.7%
""")

# %% [markdown]
# ---
# ## Project 4: NLP Project
#
# ### Task List
# - [ ] Load text dataset (e.g., IMDb reviews, spam)
# - [ ] EDA: text length distribution, word frequency, class balance
# - [ ] Implement text preprocessing function
# - [ ] Create TF-IDF feature extractor with n-grams
# - [ ] Build sklearn Pipeline
# - [ ] Train 3 models (Naive Bayes, Logistic Regression, SVM)
# - [ ] Compare performance with classification report
# - [ ] Plot confusion matrix
# - [ ] Error analysis: examine misclassified examples
# - [ ] Test with custom input text
# - [ ] Save the pipeline with joblib
# - [ ] Write README with results

# %%
# Implement NLP project
print("""
NLP Pipeline:
  Text -> clean() -> TfidfVectorizer -> Classifier -> Prediction

Preprocessing steps:
  1. Lowercase
  2. Remove punctuation/numbers
  3. Remove stopwords
  4. Lemmatization (optional)
  5. Strip whitespace
""")

# %% [markdown]
# ---
# ## Project 5: Production Prediction API
#
# ### Task List
# - [ ] Train and save a model with joblib
# - [ ] Create FastAPI app with endpoints
# - [ ] Define Pydantic schemas with validation
# - [ ] Add model loading on startup
# - [ ] Add error handling (model not loaded, invalid input)
# - [ ] Write tests with TestClient
# - [ ] Create Dockerfile (multi-stage, <300MB)
# - [ ] Create .dockerignore
# - [ ] Create docker-compose.yml
# - [ ] Add Docker HEALTHCHECK
# - [ ] Configure logging
# - [ ] Add CI/CD workflow (GitHub Actions)
# - [ ] Test with curl/Postman
# - [ ] Write README with deployment instructions

# %%
# Implement deployment project
print("""
Project Structure:
prediction_api/
  app/
    __init__.py
    main.py
    schemas.py
    model.py
  models/
    model.pkl
  tests/
    test_api.py
  Dockerfile
  docker-compose.yml
  .dockerignore
  .github/workflows/
    deploy.yml
  requirements.txt
  README.md
""")

# %% [markdown]
# ---
# ## Final Deliverables Checklist
#
# ### GitHub Repository
# - [ ] Public GitHub repo with a good name
# - [ ] Clean README.md with:
#   - Project title and description
#   - Architecture diagram (ASCII or image)
#   - Setup and installation instructions
#   - Usage examples
#   - Results and evaluation
#   - Technologies used
#
# ### Code Quality
# - [ ] Modular code (separate files for different concerns)
# - [ ] Functions have docstrings
# - [ ] Type hints used
# - [ ] Constants defined at top or in config
# - [ ] No hardcoded secrets or paths
#
# ### Testing
# - [ ] At least basic tests for core functionality
# - [ ] Tests are runnable with pytest
#
# ### Documentation
# - [ ] README is comprehensive
# - [ ] Code comments explain why, not what
# - [ ] Example usage is documented
#
# ### Polish
# - [ ] requirements.txt is complete and accurate
# - [ ] .gitignore file present
# - [ ] No unnecessary files in repo
# - [ ] No print statements in production code (except logging)
# - [ ] Code follows PEP 8 (use black or flake8)

# %%
# Final check: print your project summary
print("Project Summary:")
print(f"  Project chosen: ")
print(f"  Dataset: ")
print(f"  Best model/metric: ")
print(f"  GitHub repo: ")
print(f"  Key learnings: ")
