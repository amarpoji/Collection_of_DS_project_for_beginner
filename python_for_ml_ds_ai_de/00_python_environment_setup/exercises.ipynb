# %% [markdown]
# # Module 00 Exercises — Python Environment Setup
#
# ## Instructions
# Solve each exercise. Do NOT look at solutions until you've attempted each one.

# %% [markdown]
# ## Exercise 1: Environment Check
# Write a script that prints: your Python version, your OS, and whether you're in a virtual environment.

# %%
# Your code here
import sys

# Print Python version

# Print OS info

# Check virtual environment

# %% [markdown]
# ## Exercise 2: Package Installation
# Install the following packages and verify each imports correctly:
# - seaborn
# - scipy
# - requests

# %%
# Your code here
# !pip install seaborn scipy requests

# Verify imports

# %% [markdown]
# ## Exercise 3: requirements.txt
# Create a list of packages you'd include in a data science requirements.txt. Write them as a Python string.

# %%
# Your code here
requirements = """
# Add at least 8 packages with versions
"""
print(requirements)

# %% [markdown]
# ## Exercise 4: First Data Pipeline
# Create a small pandas DataFrame with 3 rows of student data (name, grade, passed: True/False). Print summary statistics.

# %%
# Your code here
import pandas as pd

# Create DataFrame

# Print summary

# %% [markdown]
# ## Exercise 5: Git Setup Script
# Write a bash script (as a Python string) that:
# 1. Initializes a git repo
# 2. Creates a .gitignore
# 3. Creates a requirements.txt
# 4. Makes the first commit

# %%
# Your code here
setup_script = """
# Write git setup commands here
"""
print(setup_script)

# %% [markdown]
# ## Exercise 6: Package Version Check
# Write a function that checks if a package is installed and returns its version (or 'Not installed').

# %%
# Your code here
def check_package(package_name: str) -> str:
    """Check if a package is installed."""
    pass  # Replace with your code

# Test
print(check_package("pandas"))
print(check_package("nonexistent_package"))
