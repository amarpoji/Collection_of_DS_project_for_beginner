# %% [markdown]
# # Module 04: Data Structures Deep Dive — Exercises
#
# Complete these exercises to master Python's data structures for ML/DS work.

# %% [markdown]
# ## Exercise 1: List vs Set Performance
#
# Generate a list of 100,000 random integers. Then:
# 1. Create a set from the list
# 2. Time how long it takes to check if 100 random numbers are in the **list** (use `in` operator)
# 3. Time how long it takes to check if the same 100 numbers are in the **set**
# 4. Print the ratio of list time to set time
# 5. Also compute and print the number of unique values (using `len(set)`)

# %%
import random
import time

random.seed(42)

# Your code here
# 1. Generate 100000 random integers
# 2. Create set
# 3. Generate 100 test numbers
# 4. Time list membership
# 5. Time set membership
# 6. Print results

# %% [markdown]
# ## Exercise 2: Class Distribution with Counter
#
# Given a list of class labels (strings), use `Counter` to:
# 1. Find the 3 most common classes
# 2. Find the class that appears the least
# 3. Calculate the percentage of each class
# 4. Identify if there's class imbalance (any class < 10% of total)
# 5. Print a simple ASCII bar chart showing class frequencies

# %%
from collections import Counter

labels = [
    "cat", "dog", "bird", "cat", "dog", "cat", "fish", "bird",
    "cat", "dog", "cat", "cat", "dog", "bird", "fish", "cat",
    "dog", "dog", "cat", "bird", "cat", "dog", "cat", "fish",
    "cat", "dog", "cat", "cat", "dog", "dog", "bird", "cat",
    "rabbit", "cat", "dog", "cat", "hamster", "bird"
]

# Your code here

# %% [markdown]
# ## Exercise 3: Grouping with defaultdict
#
# You have a list of (category, value, timestamp) triples. Use `defaultdict` to:
# 1. Group all values by category
# 2. For each category, compute the min, max, mean, and count
# 3. Group values by both category AND the hour of the timestamp (extract hour from timestamp string)
# 4. Use nested `defaultdict` for the hierarchical grouping

# %%
from collections import defaultdict

data = [
    ("sales", 150, "2024-01-15 09:30:00"),
    ("sales", 200, "2024-01-15 10:15:00"),
    ("signups", 25, "2024-01-15 09:45:00"),
    ("sales", 175, "2024-01-15 09:55:00"),
    ("signups", 30, "2024-01-15 10:30:00"),
    ("pageviews", 500, "2024-01-15 09:00:00"),
    ("pageviews", 450, "2024-01-15 10:00:00"),
    ("signups", 20, "2024-01-15 11:00:00"),
    ("sales", 300, "2024-01-15 11:30:00"),
    ("pageviews", 600, "2024-01-15 11:15:00")
]

# Your code here

# %% [markdown]
# ## Exercise 4: Sliding Window Statistics with deque
#
# Simulate a real-time data stream of 1000 sensor readings (generate random floats between 0 and 1).
#
# 1. Use `deque(maxlen=50)` as a sliding window
# 2. For each new reading, compute and store:
#    - Current value
#    - Window mean
#    - Window max
#    - Window min
# 3. Print readings where the current value deviates from the window mean by more than 2 standard deviations (anomaly detection)
# 4. Count how many anomalies were detected

# %%
from collections import deque
import random
import math

random.seed(42)

# Your code here
# 1. Generate 1000 readings with a few injected spikes
# 2. Use deque(maxlen=50)
# 3. Detect anomalies
# 4. Print count and details

# %% [markdown]
# ## Exercise 5: Top-K Feature Importance with heapq
#
# Given a dictionary of feature names and their importance scores:
# 1. Find the top 5 features using `heapq.nlargest`
# 2. Find the bottom 3 features using `heapq.nsmallest`
# 3. Find all features with importance > 0.5 (using a list comprehension)
# 4. Create a new dict with only the top-5 features
# 5. Compute and print the cumulative importance of the top-5 features

# %%
import heapq
import random

random.seed(42)

# Generate 50 features with random importance scores
feature_importance = {}
for i in range(50):
    feature_importance["feature_" + str(i)] = random.random()

# Your code here

# %% [markdown]
# ## Exercise 6: Sorted List Operations with bisect
#
# You are building a real-time leaderboard for model performance scores.
#
# 1. Start with an empty sorted list
# 2. Insert 20 random scores between 0 and 1, keeping the list sorted after each insertion (use `bisect.insort`)
# 3. After inserting all scores, find the rank (position + 1) of a specific score using `bisect_left`
# 4. Find all scores above the 90th percentile
# 5. Find scores that fall within a specific range [0.3, 0.7] using `bisect_left` and `bisect_right`

# %%
import bisect
import random

random.seed(42)

# Your code here
