# %% [markdown]
# # Module 05: File Handling & OS — Exercises
#
# Practice reading, writing, and organizing files for ML workloads.

# %% [markdown]
# ## Exercise 1: Read a CSV and Compute Statistics
#
# Write code that:
# 1. Creates a CSV file called `heights.csv` with columns: name, height_cm, weight_kg
# 2. Adds at least 5 rows of data
# 3. Reads the CSV back using `csv.DictReader`
# 4. Computes and prints the average height and average weight

# %%
# Your code here
import csv

# Step 1: Write CSV


# Step 2: Read CSV and compute averages

# %% [markdown]
# ## Exercise 2: JSONL Dataset Reader
#
# You have a JSONL file where each line is a dataset sample with fields: `id`, `text`, `label`.
#
# 1. Create 8 sample entries
# 2. Write them to `reviews.jsonl`
# 3. Read the file back and count how many samples have label `"positive"` vs `"negative"`
# 4. Print the counts

# %%
# Your code here
import json

# Create samples


# Write JSONL


# Read and count labels

# %% [markdown]
# ## Exercise 3: Directory Organizer
#
# Use `pathlib` to:
# 1. Create a directory structure: `ml_project/data/raw/`, `ml_project/models/`, `ml_project/output/`
# 2. Create dummy files: `ml_project/data/raw/dataset.csv`, `ml_project/models/model.pkl`, `ml_project/output/predictions.csv`
# 3. List all `.csv` files in the `ml_project` directory tree recursively
# 4. Print each CSV file's size in bytes

# %%
# Your code here
from pathlib import Path

# Create directory structure


# Create dummy files


# Find and report CSV files

# %% [markdown]
# ## Exercise 4: Model Artifact Manager
#
# Write a function `save_model_artifact(model_info, filepath)` that:
# 1. Takes a dict with keys: `name`, `accuracy`, `params` (dict), `timestamp`
# 2. Saves it as a JSON file at `filepath`
# 3. Also saves a companion metadata file with a `filepath_meta` that includes: `model_file`, `model_info.accuracy`, and `file_size`
# 4. Returns the size of the saved files
#
# Then call it with sample data and print the result.

# %%
# Your code here
import json
from pathlib import Path

def save_model_artifact(model_info, filepath):
    # Save main artifact
    
    # Save companion metadata
    
    # Return file sizes
    pass

# Test with sample data

# %% [markdown]
# ## Exercise 5: Large File Processing
#
# Generate a large text file (1000 lines) and process it line by line WITHOUT loading the entire file into memory.
#
# 1. Create `large_log.txt` with 1000 lines, each containing "Line N: Some log data"
# 2. Read the file line by line and count how many lines contain the word "log"
# 3. Print the count and the last line of the file
# 4. Verify you only used `for line in f` (not `read()` or `readlines()`)

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: File Metadata Report
#
# Write code that:
# 1. Creates 3 files of different sizes (small: 10 bytes, medium: 100 bytes, large: 1000 bytes)
# 2. For each file, prints: filename, size in bytes, last modified time (human readable)
# 3. Uses `pathlib.Path.stat()` for metadata
# 4. Shows which file is the largest

# %%
# Your code here
