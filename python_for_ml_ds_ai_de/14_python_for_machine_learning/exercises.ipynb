# %% [markdown]
# # Module 14: Python for Machine Learning — Exercises
#
# Practice building, evaluating, and tuning ML models.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    roc_auc_score, confusion_matrix, ConfusionMatrixDisplay,
    mean_squared_error, r2_score
)
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')
print('Setup complete')

# %% [markdown]
# ### Exercise 1: Linear Regression on California Housing
#
# Train a Linear Regression model on California Housing. Report MSE, RMSE, MAE, and R². Then interpret the most important positive and negative coefficients.

# %%
# Your code here
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# ### Exercise 2: Decision Tree Classifier on Iris
#
# Train a Decision Tree classifier on the Iris dataset. Visualize the tree. Report accuracy and the confusion matrix. Try different max_depth values (2, 4, 6) and compare.

# %%
# Your code here
from sklearn.tree import plot_tree

# %% [markdown]
# ### Exercise 3: Cross-Validation Comparison
#
# Compare 5-fold cross-validation scores for Logistic Regression, Decision Tree, and Random Forest on the Titanic dataset. Use accuracy as the scoring metric. Which model has the best mean CV score? Which has the lowest variance?

# %%
# Your code here
# Load Titanic, prepare features, run cross_val_score for each model

# %% [markdown]
# ### Exercise 4: ROC-AUC Analysis
#
# Train a Logistic Regression and a Random Forest on Titanic. Plot ROC curves for both models on the same axes. Which model has a higher AUC?

# %%
# Your code here
from sklearn.metrics import RocCurveDisplay

# %% [markdown]
# ### Exercise 5: SVM with Different Kernels
#
# Train SVM classifiers with linear, rbf, and polynomial kernels on the Iris dataset (binary: setosa vs rest). Compare accuracy and training time. Which kernel performs best?

# %%
# Your code here
# Convert to binary classification problem

# %% [markdown]
# ### Exercise 6: K-Means with Elbow Method
#
# Apply K-Means clustering to the California Housing dataset (using MedInc, Latitude, Longitude). Use the elbow method (inertia vs k) to find the optimal number of clusters. Visualize the clusters on a scatter plot.

# %%
# Your code here
# Compute inertia for k=1..10 and plot the elbow curve

# %% [markdown]
# ### Exercise 7: PCA for Visualization
#
# Apply PCA to the Iris dataset (4 features → 2 components). Plot the 2D PCA projection colored by species. How much variance is explained by the first two components?

# %%
# Your code here

# %% [markdown]
# ### Exercise 8: Hyperparameter Tuning
#
# Use GridSearchCV to tune an SVC on the Titanic dataset. Search over C=[0.1, 1, 10], gamma=['scale', 'auto', 0.1], kernel=['rbf', 'linear']. Report the best parameters and the test set accuracy.

# %%
# Your code here

# %% [markdown]
# ### Exercise 9: Model Interpretation
#
# Train a Random Forest on the Titanic dataset. Extract and visualize feature importances. Which are the top 3 most important features? Does this align with your domain knowledge?

# %%
# Your code here

# %% [markdown]
# ### Exercise 10: Full ML Workflow — Putting It All Together
#
# On the Iris dataset: split data (80/20 stratified), scale features, train KNN (k=3,5,7), select best k via cross-validation, evaluate on test set with accuracy and confusion matrix, and visualize the decision boundary using PCA-reduced data.

# %%
# Your code here
# Complete ML workflow step by step
