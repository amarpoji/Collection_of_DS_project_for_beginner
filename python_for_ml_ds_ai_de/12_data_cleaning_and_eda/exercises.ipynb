# %% [markdown]
# # Module 12 Exercises — Data Cleaning & EDA
#
# Practice cleaning and exploring a messy dataset.

# %% [markdown]
# ## Exercise 1: Handle Missing Values
#
# Create a small DataFrame with NaN values. Use at least 3 different methods to handle them (dropna, fillna with mean, forward fill, interpolate).

# %%
import pandas as pd
import numpy as np

# Create data with missing values
data = {"A": [1, 2, np.nan, 4, 5],
        "B": [np.nan, 2, 3, np.nan, 5],
        "C": [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

# Your code: try dropna(), fillna(), interpolate()



print("Original:")
print(df)
print()
# Show your cleaned versions

# %% [markdown]
# ## Exercise 2: Detect and Handle Outliers
#
# Use IQR method to find and cap outliers in a dataset.

# %%
np.random.seed(42)
data = np.concatenate([np.random.normal(50, 10, 95),  # normal data
                       np.array([5, 8, 150, 160, 200])])  # outliers
values = pd.Series(data)

# Your code: find Q1, Q3, IQR, lower/upper bounds
# Count outliers, then cap them



print("Original stats:", values.describe())
# Show cleaned data

# %% [markdown]
# ## Exercise 3: Clean Inconsistent Text Data
#
# Fix casing, whitespace, and standardize categories.

# %%
raw = pd.Series(["  data scientist  ", "ML ENGINEER", "Data Scientist", 
                  "ml engineer", "DATA scientist", "  Data  Engineer  "])

# Your code: strip whitespace, standardize to title case, count unique



print("Original unique:", raw.nunique())
# Show cleaned

# %% [markdown]
# ## Exercise 4: EDA on Titanic Dataset
#
# Load Titanic data (seaborn.load_dataset('titanic')). Perform complete EDA: shape, info, missing %, describe, correlations, groupby stats.

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')

# Your complete EDA:
# 1. Shape and info
# 2. Missing data percentage
# 3. Survival rate by sex/class
# 4. Age distribution statistics
# 5. Correlation matrix of numeric features



print("Titanic EDA complete")

# %% [markdown]
# ## Exercise 5: Feature Engineering from Dates
#
# Create date-based features from a datetime column.

# %%
dates = pd.date_range('2023-01-01', periods=100, freq='D')
df = pd.DataFrame({'date': dates, 'sales': np.random.randint(100, 500, 100)})

# Your code: extract year, month, day, dayofweek, is_weekend
# Then group by dayofweek to find average sales



print("Feature engineering complete")
