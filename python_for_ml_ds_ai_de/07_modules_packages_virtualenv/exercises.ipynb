# %% [markdown]
# # Module 07: Modules, Packages & Virtualenv — Exercises
#
# Practice creating modules, packages, and structuring ML projects.

# %% [markdown]
# ## Exercise 1: The `__name__` Guard
#
# Create a file `calculator.py` with:
# 1. Functions: `add(a, b)`, `subtract(a, b)`, `multiply(a, b)`, `divide(a, b)`
# 2. A `if __name__ == '__main__':` block that tests all four functions
# 3. Import the module in this notebook and call `add(5, 3)`
# 4. Print the result — verify the test code didn't run

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Create a Package
#
# Create a package called `ml_utils` with this structure:
#
# ```
# ml_utils/
#   __init__.py       # exports: load_csv, train_test_split
#   data/
#     __init__.py
#     io.py           # load_csv function
#   model/
#     __init__.py
#     split.py        # train_test_split function
# ```
#
# Each function should print what it does and return a simple result. Import from the package and call both functions.

# %%
# Your code here
from pathlib import Path

# %% [markdown]
# ## Exercise 3: Import Styles
#
# Given this package structure:
# ```
# analysis/
#   __init__.py
#   stats.py         # contains: mean(), std()
#   utils/
#     __init__.py
#     helpers.py     # contains: normalize()
# ```
#
# Create the structure and then import/use:
# 1. `from analysis import mean` (through __init__.py re-export)
# 2. `from analysis.utils.helpers import normalize` (absolute path)
# 3. Inside `analysis/utils/helpers.py`, use a relative import to import `mean` from `analysis.stats`

# %%
# Your code here

# %% [markdown]
# ## Exercise 4: Create a requirements.txt
#
# Create a `requirements.txt` file for an ML project that needs:
# 1. numpy >= 1.24
# 2. pandas == 2.0.3
# 3. scikit-learn >= 1.2, < 1.4
# 4. matplotlib compatible release ~= 3.7
# 5. jupyter (any version)
# 6. pytest >= 7 (for development)
#
# Write the file and print its contents to verify.

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Module Search Path
#
# Write code that:
# 1. Prints `sys.path`
# 2. Adds a custom directory `'my_custom_modules'` to the front of `sys.path`
# 3. Creates a file `my_custom_modules/hello.py` with a function `greet()`
# 4. Imports and calls `greet()` from the custom path
# 5. Removes the custom path from `sys.path`

# %%
# Your code here

# %% [markdown]
# ## Exercise 6: Create a Console Script
#
# Create a package `greeter` with:
# 1. `__init__.py`
# 2. `greet.py` with a `say_hello(name)` function that prints "Hello, {name}!"
# 3. A `main()` function in `greet.py` that reads a name from command line arguments (use `sys.argv`)
# 4. Under `if __name__ == '__main__':`, call `main()`
#
# Test it by running the script.

# %%
# Your code here
