# %% [markdown]
# # Module 10: Data Visualization — Exercises
#
# **Datasets:** Iris, Titanic
# **Objective:** Practice creating and customizing visualizations with matplotlib and seaborn
#
# Complete each exercise below. Use both pyplot and OO API where appropriate.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %matplotlib inline
sns.set_theme()

# Load datasets
iris_data = load_iris()
iris = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
iris['species'] = iris_data.target_names[iris_data.target]

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
titanic = pd.read_csv(url)

print('Datasets loaded successfully.')

# %% [markdown]
# ### Exercise 1: Basic Matplotlib (OO API)
#
# Create a 2-panel figure:
# - Left: scatter plot of sepal length vs petal length (Iris), colored by species
# - Right: line plot of the first 50 samples of sepal length and sepal width
# Use the OO API (no pyplot). Add labels, titles, and legends.

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 2: Histograms & Distributions
#
# For the Titanic dataset:
# 1. Create a histogram of Age with 25 bins, colored steelblue with black edges
# 2. Overlay a KDE on the histogram (use density=True)
# 3. Create a second histogram comparing Age distributions of survivors vs non-survivors (alpha=0.5, overlapping)
# 4. Add vertical lines for mean and median Age

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 3: Box Plots & Outliers
#
# 1. Create a box plot of Age by Pclass on the Titanic dataset
# 2. Create a box plot of Fare by Embarked port
# 3. Use the IQR method to count how many Fare outliers exist for each Pclass
# 4. Create a horizontal box plot of Fare by Pclass

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 4: Correlation Heatmap
#
# 1. Compute the correlation matrix of all numeric columns in the Titanic dataset
# 2. Create a heatmap using matplotlib's imshow (not seaborn) with the 'coolwarm' colormap
# 3. Annotate each cell with the correlation value (rounded to 2 decimals)
# 4. Mask the upper triangle (set those values to NaN or don't display them)

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 5: Seaborn Pairplot & Jointplot
#
# 1. Use sns.pairplot() on the Iris dataset with hue='species' and diag_kind='hist'
# 2. Create a sns.jointplot() of petal length vs petal width with kind='kde' for the Iris dataset
# 3. Create a sns.jointplot() of Age vs Fare from Titanic with kind='hex'
# 4. Which Iris species is easiest to separate? Which features separate best?

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 6: Seaborn Categorical Plots
#
# 1. Create a count plot of 'Sex' on Titanic, colored by 'Survived'
# 2. Create a bar plot of survival rate by 'Pclass' with confidence intervals
# 3. Create a violin plot of 'Age' by 'Pclass', split by 'Survived'
# 4. Create a catplot with col='Sex', x='Pclass', y='Survived', kind='point'

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 7: lmplot & Custom Regression
#
# 1. Use sns.lmplot() to plot Age vs Fare from Titanic, colored by Survived
# 2. Add a custom annotation highlighting the cluster of high-fare survivors
# 3. Create a polynomial regression plot (order=2) of petal length vs petal width from Iris
# 4. Customize colors, sizes, and alpha for better readability

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 8: Complex Subplots with GridSpec
#
# Create a 3x3 figure with:
# - Top row: histogram of Age (left), histogram of Fare (center), box plot of Age by Pclass (right)
# - Middle row (spanning all 3 columns): scatter plot of Age vs Fare, colored by Survived
# - Bottom row: count plot of Sex (left), count plot of Embarked (center), pie chart of Pclass (right)
# Use GridSpec for this layout.

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 9: Boxen Plot & Advanced Distribution
#
# 1. Create a boxenplot of Fare by Pclass on the Titanic dataset
# 2. Compare it side-by-side with a traditional box plot
# 3. Create a violin plot of Age by Sex and Survived
# 4. Create an ecdfplot (empirical cumulative distribution) of Age by Survived

# %%
# Your code here
pass

# %% [markdown]
# ### Exercise 10: Full EDA Visualization Report
#
# Create a mini EDA report for the Titanic dataset in a single figure with at least 6 panels. Include:
# - A correlation heatmap
# - Survival distribution
# - Age distribution by survival
# - Fare analysis
# - Class analysis
# - Gender analysis
#
# Add annotations summarizing key ML-relevant findings.

# %%
# Your code here
pass
