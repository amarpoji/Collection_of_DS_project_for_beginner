# %% [markdown]
# # Module 16: ML Workflow End-to-End — Exercises
#
# Practice building complete ML workflows with pipelines, evaluation, interpretation, and tracking.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing, load_iris, load_breast_cancer
from sklearn.model_selection import (
    train_test_split, cross_val_score, learning_curve, validation_curve, GridSearchCV
)
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import (
    mean_squared_error, r2_score, accuracy_score, f1_score,
    confusion_matrix, ConfusionMatrixDisplay, classification_report
)
from sklearn.inspection import permutation_importance
import joblib
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')
print('Setup complete')

# %% [markdown]
# ### Exercise 1: Build a Complete Pipeline
#
# Build a Pipeline for the California Housing dataset that: imputes missing values (use SimpleImputer even if none missing), scales features with StandardScaler, and trains a Ridge regression. Evaluate with 5-fold cross-validation and report mean R².

# %%
# Your code here

# %% [markdown]
# ### Exercise 2: Learning Curve Analysis
#
# Generate a learning curve for the California Housing pipeline (from Ex1). Use train_sizes from 0.1 to 1.0. Plot both training and validation scores. Is the model overfitting or underfitting? How can you tell?

# %%
# Your code here

# %% [markdown]
# ### Exercise 3: Validation Curve for alpha
#
# Create a validation curve for the alpha parameter of Ridge regression on California Housing. Search alpha values from 0.001 to 100 (log scale). What is the optimal alpha?

# %%
# Your code here

# %% [markdown]
# ### Exercise 4: Confusion Matrix and Classification Report
#
# Load the Breast Cancer dataset from sklearn. Build a complete pipeline (scaler + SVM). Generate a confusion matrix and classification report. What is the recall for the positive class?

# %%
# Your code here
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# ### Exercise 5: Permutation Importance
#
# On the California Housing model from Ex1, compute permutation feature importance with n_repeats=5. Which are the top 3 most important features? Plot the results.

# %%
# Your code here

# %% [markdown]
# ### Exercise 6: Experiment Tracking with MLflow
#
# Use MLflow to track 3 different models on California Housing: LinearRegression, Ridge(alpha=1.0), and RandomForestRegressor(n_estimators=50). Log R² and RMSE for each. Compare the runs.

# %%
# Your code here
try:
    import mlflow
    from mlflow.models import infer_signature
except ImportError:
    print('MLflow not installed')

# %% [markdown]
# ### Exercise 7: Model Serialization
#
# Train a Random Forest classifier on the Iris dataset. Save the model with joblib. Load it back and verify that predictions match. Then save a compressed version (compress=3) and compare file sizes.

# %%
# Your code here

# %% [markdown]
# ### Exercise 8: SHAP Interpretation
#
# Train a Random Forest classifier on the Breast Cancer dataset. Use SHAP to explain predictions for 5 test samples. Create a waterfall plot for one prediction and a summary plot for all features.

# %%
# Your code here
try:
    import shap
except ImportError:
    print('SHAP not installed')

# %% [markdown]
# ### Exercise 9: GridSearch with Pipeline
#
# Combine everything: create a Pipeline for Titanic (impute + scale + onehot + RF classifier). Use GridSearchCV to tune n_estimators=[50, 100, 200] and max_depth=[3, 5, 10, None]. Report best params and test accuracy.

# %%
# Your code here

# %% [markdown]
# ### Exercise 10: Complete End-to-End Workflow
#
# This is the capstone exercise. On the California Housing dataset:
# 1. Create a Pipeline with ColumnTransformer (scale numeric)
# 2. Use GridSearchCV to tune a RandomForest (n_estimators, max_depth)
# 3. Generate learning curve for the best model
# 4. Compute permutation feature importance
# 5. Log all results with MLflow (params, metrics, model, feature importance plot)
# 6. Save the best pipeline with joblib
# 7. Load and verify predictions match
#
# Create a summary report explaining each step.

# %%
# Your code here
