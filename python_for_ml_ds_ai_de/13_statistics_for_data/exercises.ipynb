# %% [markdown]
# # Module 13: Statistics for Data — Exercises
#
# Practice your statistical analysis skills. Complete each exercise below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.datasets import load_iris, fetch_california_housing
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid')
print('Setup complete')

# %% [markdown]
# ### Exercise 1: Descriptive Statistics
#
# Load the Iris dataset and compute the five-number summary (min, Q1, median, Q3, max) for each feature. Identify which feature has the highest variance and explain what that implies.

# %%
# Your code here
iris = sns.load_dataset('iris')
# Compute five-number summary for each numeric column
# Determine which feature has the highest variance

# %% [markdown]
# ### Exercise 2: Central Limit Theorem Simulation
#
# Simulate drawing samples from a uniform distribution U(0, 10). Show that the distribution of sample means becomes normal as sample size increases. Plot histograms for n=2, n=10, and n=50.

# %%
# Your code here
# Generate a population from uniform distribution
# Draw many samples at each sample size
# Plot the sampling distributions

# %% [markdown]
# ### Exercise 3: Hypothesis Testing
#
# Load the Titanic dataset. Test whether the mean fare differs between survivors and non-survivors using a two-sample t-test. Report the t-statistic, p-value, and your conclusion.

# %%
# Your code here
# Load Titanic
# Separate fare by survival
# Conduct t-test and report results

# %% [markdown]
# ### Exercise 4: ANOVA on California Housing
#
# Bin California housing median income into 4 quartile groups. Perform a one-way ANOVA to test if median house values differ significantly across income groups. Report F-statistic and p-value.

# %%
# Your code here
# Load California Housing
# Create income quartile bins
# Perform ANOVA

# %% [markdown]
# ### Exercise 5: Chi-Square Test
#
# On the Titanic dataset, test whether passenger class (pclass) and survival are independent. Use a chi-square test of independence. Report the chi-square statistic, p-value, and interpretation.

# %%
# Your code here
# Create contingency table
# Perform chi-square test

# %% [markdown]
# ### Exercise 6: Feature Selection with Statistical Tests
#
# On the California Housing dataset, use SelectKBest with f_regression to select the top 3 features for predicting MedHouseVal. Which features are selected and why?

# %%
# Your code here
from sklearn.feature_selection import SelectKBest, f_regression
# Load data, select features, report results

# %% [markdown]
# ### Exercise 7: Correlation Analysis
#
# On the California Housing dataset, compute both Pearson and Spearman correlations between all features. Find any features where the two correlations differ substantially. What does this tell you about the relationship?

# %%
# Your code here
# Compute both correlation matrices
# Find features with largest Pearson-Spearman differences

# %% [markdown]
# ### Exercise 8: Bayes Theorem Application
#
# A spam filter detects 95% of spam emails correctly (sensitivity). It incorrectly flags 2% of legitimate emails as spam (false positive rate). If 10% of all emails are spam, what is the probability that an email flagged as spam is actually spam? Write a function that computes this.

# %%
# Your code here
def bayes_spam(prior_spam, sensitivity, false_positive_rate):
    pass

# Test your function with the values above

# %% [markdown]
# ### Exercise 9: Effect Size Calculation
#
# For the t-test you performed in Exercise 3 (fare difference by survival), compute Cohen's d effect size. Interpret whether the effect is small, medium, or large.

# %%
# Your code here
# Compute Cohen's d from Exercise 3 results

# %% [markdown]
# ### Exercise 10: Putting It All Together
#
# Select the Iris dataset. For each pair of species (setosa-versicolor, setosa-virginica, versicolor-virginica), perform a t-test on each feature. Create a heatmap of p-values. Which features best separate which species pairs?

# %%
# Your code here
# Pairwise t-tests for all features
# Create a p-value heatmap
