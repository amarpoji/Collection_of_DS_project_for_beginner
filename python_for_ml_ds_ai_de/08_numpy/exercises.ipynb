# %% [markdown]
# # Module 08: NumPy — Exercises
#
# Practice NumPy fundamentals with ML-focused problems.

# %% [markdown]
# ## Exercise 1: Array Creation and Inspection
#
# Create:
# 1. A 1D array of 10 zeros
# 2. A 3x3 array of ones
# 3. A 4x4 identity matrix
# 4. An array of 20 evenly spaced numbers between 0 and 1
# 5. An array of odd numbers from 1 to 19
# 6. Print the dtype, shape, size, and ndim of each array

# %%
import numpy as np

# Your code here

# %% [markdown]
# ## Exercise 2: Reshaping and Transposing
#
# Given an array of 24 elements:
# 1. Create it with `np.arange(24)`
# 2. Reshape to (4, 6)
# 3. Reshape to (2, 3, 4) — 3D!
# 4. Transpose the (4, 6) matrix to (6, 4)
# 5. Flatten it back and verify it matches the original

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Performance Comparison
#
# Compare Python loops vs NumPy vectorization:
# 1. Create a Python list and a NumPy array of 1,000,000 random numbers
# 2. Time how long it takes to compute `sin(x)^2 + cos(x)^2` for each element
# 3. For the Python version, use a list comprehension
# 4. For NumPy, use vectorized operations
# 5. Print both times and the speedup factor
# 6. Verify the result should be close to 1.0 (trig identity)

# %%
# Your code here
import time
import math

# %% [markdown]
# ## Exercise 4: Broadcasting
#
# You have a 5x3 feature matrix X (5 samples, 3 features):
# 1. Create X with random values (seed=42)
# 2. Compute the mean and std of each feature (column)
# 3. Standardize X using broadcasting: `(X - mean) / std`
# 4. Verify that each feature in the result has mean ~0 and std ~1
# 5. Add a bias column (all 1s) to the standardized matrix using broadcasting

# %%
# Your code here

# %% [markdown]
# ## Exercise 5: Boolean Indexing
#
# Given an array of 50 random integers between 0 and 100:
# 1. Find all values greater than 75
# 2. Find all values between 30 and 60 (inclusive)
# 3. Replace all values below 20 with 0
# 4. Replace all values above 80 with 80
# 5. Count how many values are exactly 50
# 6. Print the original and modified arrays

# %%
# Your code here
np.random.seed(42)

# %% [markdown]
# ## Exercise 6: Aggregation
#
# Create a 10x4 array of random numbers (10 samples, 4 features):
# 1. Compute the mean, min, max, and std for each feature (axis=0)
# 2. Compute the mean, min, max, and std for each sample (axis=1)
# 3. Find the feature with the highest variance
# 4. Find the sample with the highest mean value
# 5. Print all results

# %%
# Your code here
np.random.seed(42)

# %% [markdown]
# ## Exercise 7: Linear Algebra
#
# 1. Create two 3x3 random matrices A and B
# 2. Compute `A @ B` and `B @ A` — are they the same?
# 3. Compute the determinant of A using `linalg.det()`
# 4. Compute the inverse of A using `linalg.inv()`
# 5. Verify that `A @ inv(A)` is close to the identity matrix
# 6. Compute eigenvalues and eigenvectors of A

# %%
# Your code here
from numpy import linalg

# %% [markdown]
# ## Exercise 8: Train-Test Split from Scratch
#
# Write a function `my_train_test_split(X, y, test_size=0.2, random_seed=42)` that:
# 1. Sets the random seed for reproducibility
# 2. Creates a permutation of indices
# 3. Splits into train and test sets
# 4. Returns X_train, X_test, y_train, y_test
# 5. Test with a 100-sample dataset and print the shapes

# %%
# Your code here


# Test
np.random.seed(42)
X = np.random.randn(100, 5)
y = np.random.randint(0, 2, 100)

# %% [markdown]
# ## Exercise 9: Mean Squared Error
#
# Write a function `mse(y_true, y_pred)` and `rmse(y_true, y_pred)` using only NumPy:
# 1. Both should be fully vectorized (no loops)
# 2. Test with random data
# 3. Verify against a manual calculation for a small example

# %%
# Your code here

# %% [markdown]
# ## Exercise 10: One-Hot Encoding
#
# Write a function `one_hot(y, num_classes)` that converts a 1D array of class labels into a 2D one-hot encoded matrix.
#
# Example: `one_hot([0, 2, 1], 3)` →
# ```
# [[1, 0, 0],
#  [0, 0, 1],
#  [0, 1, 0]]
# ```
#
# Do NOT use loops — use NumPy indexing (`np.eye(num_classes)[y]`).

# %%
# Your code here


# Test
y = np.array([0, 2, 1, 2, 0, 1])
